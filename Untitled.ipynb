# %%
# !pip3 install beautifulsoup4
# Out:
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# Requirement already satisfied: beautifulsoup4 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (4.9.3)
# Requirement already satisfied: soupsieve>1.2; python_version >= "3.0" in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from beautifulsoup4) (2.0.1)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import re
import time
from datetime import datetime
import matplotlib.dates as mdates
import matplotlib.ticker as ticker
from urllib.request import urlopen
from bs4 import BeautifulSoup
import requests

# %%
no_pages = 2

def get_data(pageNo):  
    headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:66.0) Gecko/20100101 Firefox/66.0", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

    r = requests.get('https://www.amazon.com/best-sellers-books-Amazon/zgbs/books/ref=zg_bs_nav_0'+str(pageNo)+'?ie=UTF8&pg='+str(pageNo), headers=headers)#, proxies=proxies)
    content = r.content
    soup = BeautifulSoup(content)
    #print(soup)

    alls = []
    for d in soup.findAll('div', attrs={'class':'a-section a-spacing-none aok-relative'}):
        #print(d)
        name = d.find('span', attrs={'class':'zg-text-center-align'})
        n = name.find_all('img', alt=True)
        #print(n[0]['alt'])
        author = d.find('a', attrs={'class':'a-size-small a-link-child'})
        rating = d.find('span', attrs={'class':'a-icon-alt'})
        users_rated = d.find('a', attrs={'class':'a-size-small a-link-normal'})
        price = d.find('span', attrs={'class':'p13n-sc-price'})

        all1=[]

        if name is not None:
            #print(n[0]['alt'])
            all1.append(n[0]['alt'])
        else:
            all1.append("unknown-product")

        if author is not None:
            #print(author.text)
            all1.append(author.text)
        elif author is None:
            author = d.find('span', attrs={'class':'a-size-small a-color-base'})
            if author is not None:
                all1.append(author.text)
            else:    
                all1.append('0')

        if rating is not None:
            #print(rating.text)
            all1.append(rating.text)
        else:
            all1.append('-1')

        if users_rated is not None:
            #print(price.text)
            all1.append(users_rated.text)
        else:
            all1.append('0')     

        if price is not None:
            #print(price.text)
            all1.append(price.text)
        else:
            all1.append('0')
        alls.append(all1)    
    return alls

# %%
results = []
for i in range(1, no_pages+1):
    results.append(get_data(i))
flatten = lambda l: [item for sublist in l for item in sublist]
df = pd.DataFrame(flatten(results),columns=['Book Name','Author','Rating','Customers_Rated', 'Price'])
df.to_csv('amazon_products.csv', index=False, encoding='utf-8')

# %%
df = pd.read_csv("amazon_products.csv")
df.shape
# Out:
# (100, 5)

# %%
df.head(61)
# Out:
#                                             Book Name  \
# 0   Modern Comfort Food: A Barefoot Contessa Cookbook
# 1                                   Room on the Broom
# 2   Dog Man: Grime and Punishment: From the Creato...
# 3                        If Animals Kissed Good Night
# 4                    A Time for Mercy (Jake Brigance)
# 5   This Just Speaks to Me: Words to Live By Every...
# 6              Polar Express 30th anniversary edition
# 7   The Happy in a Hurry Cookbook: 100-Plus Fast a...
# 8   Encyclopedia Prehistorica Dinosaurs : The Defi...
# 9                     I Love You to the Moon and Back
# 10  School Zone - Big Preschool Workbook - Ages 4 ...
# 11  Caste (Oprah's Book Club): The Origins of Our ...
# 12        The Deep End (Diary of a Wimpy Kid Book 15)
# 13                        The Very Hungry Caterpillar
# 14                                       Midnight Sun
# 15                      Levi's Men's 517 Bootcut Jean
# 16  The Little Old Lady Who Was Not Afraid of Anyt...
# 17                                            Untamed
# 18  First Little Readers Parent Pack: Guided Readi...
# 19                                         The Return
# 20                             How to Catch a Unicorn
# 21  My First Learn to Write Workbook: Practice for...
# 22                      Little Blue Truck's Halloween
# 23                     The Spider Who Saved Christmas
# 24  One Vote Away: How a Single Supreme Court Seat...
# 25  Follow the Money: The Shocking Deep State Conn...
# 26  The Antiquarian Sticker Book: Over 1,000 Exqui...
# 27  The Home Edit: A Guide to Organizing and Reali...
# 28  The Tower of Nero (Trials of Apollo, The Book ...
# 29           Brown Bear, Brown Bear, What Do You See?
# ..                                                ...
# 31  5,000 Awesome Facts (About Everything!) (Natio...
# 32                      Spooky Pookie (Little Pookie)
# 33  Blackout: How Black America Can Make Its Secon...
# 34                               Giraffes Can't Dance
# 35     The Office: A Day at Dunder Mifflin Elementary
# 36                                               Rage
# 37  Instant Loss: Eat Real, Lose Weight: How I Los...
# 38  The Four Agreements: A Practical Guide to Pers...
# 39  Atomic Habits: An Easy & Proven Way to Build G...
# 40                              The Searcher: A Novel
# 41  School Zone - Multiplication 0-12 Flash Cards ...
# 42  Paint by Sticker Kids: Zoo Animals: Create 10 ...
# 43                          Where the Wild Things Are
# 44                        The Vanishing Half: A Novel
# 45                                   The Wonky Donkey
# 46                          Llama Llama Loves Camping
# 47               Chicka Chicka Boom Boom (Board Book)
# 48  The 5 Love Languages: The Secret to Love that ...
# 49  Think Like a Monk: Train Your Mind for Peace a...
# 50                        Pete the Cat: Trick or Pete
# 51      Leadership Strategy and Tactics: Field Manual
# 52  The Complete Mediterranean Cookbook: 500 Vibra...
# 53                            Where the Crawdads Sing
# 54                      Little Blue Truck's Christmas
# 55  American Crisis: Leadership Lessons from the C...
# 56  The Body Keeps the Score: Brain, Mind, and Bod...
# 57  Burnout: The Secret to Unlocking the Stress Cycle
# 58                                  Is This Anything?
# 59  Star Wars: 5-Minute Star Wars Stories (5-Minut...
# 60    The Trials of Apollo 3-Book Paperback Boxed Set
#
#                       Author              Rating Customers_Rated   Price
# 0                 Ina Garten  4.5 out of 5 stars             261  $21.00
# 1            Julia Donaldson  4.9 out of 5 stars           8,785   $5.00
# 2                 Dav Pilkey  4.9 out of 5 stars           6,392   $7.01
# 3          Ann Whitford Paul  4.8 out of 5 stars          18,582   $4.79
# 4               John Grisham  3.8 out of 5 stars              35  $17.97
# 5                  Hoda Kotb  3.0 out of 5 stars               2  $16.78
# 6         Chris Van Allsburg  4.9 out of 5 stars           3,677   $7.86
# 7                Steve Doocy  4.7 out of 5 stars             448  $17.99
# 8              Robert Sabuda  4.9 out of 5 stars           3,353  $19.50
# 9            Amelia Hepworth  4.9 out of 5 stars           9,779   $5.00
# 10               School Zone  4.8 out of 5 stars          26,361   $6.69
# 11          Isabel Wilkerson  4.8 out of 5 stars           5,853  $17.58
# 12               Jeff Kinney                  -1               0  $10.58
# 13                Eric Carle  4.9 out of 5 stars          21,440   $5.76
# 14           Stephenie Meyer  4.8 out of 5 stars          28,216  $16.79
# 15                         0  4.5 out of 5 stars           8,094  $31.98
# 16         Linda D. Williams  4.8 out of 5 stars             903   $4.81
# 17             Glennon Doyle  4.7 out of 5 stars          17,138  $16.79
# 18          Deborah Schecter  4.7 out of 5 stars           8,202  $11.99
# 19           Nicholas Sparks  4.6 out of 5 stars           1,997  $16.80
# 20              Adam Wallace  4.8 out of 5 stars           8,755   $5.49
# 21             Crystal Radke  4.8 out of 5 stars          25,667   $5.59
# 22            Alice Schertle  4.9 out of 5 stars           1,912   $8.64
# 23            Raymond Arroyo                  -1               0  $17.95
# 24                  Ted Cruz  4.7 out of 5 stars             274  $25.99
# 25               Dan Bongino  4.8 out of 5 stars             183  $16.80
# 26                   Odd Dot  4.8 out of 5 stars           2,067  $17.49
# 27              Clea Shearer  4.7 out of 5 stars           2,696  $14.20
# 28              Rick Riordan  4.9 out of 5 stars           1,003  $13.19
# 29           Bill Martin Jr.  4.9 out of 5 stars          15,677   $5.67
# ..                       ...                 ...             ...     ...
# 31  National Geographic Kids  4.8 out of 5 stars           8,213  $12.29
# 32            Sandra Boynton  4.9 out of 5 stars             964   $3.73
# 33             Candace Owens  4.9 out of 5 stars           2,718  $16.80
# 34             Giles Andreae  4.8 out of 5 stars          15,231   $5.00
# 35             Robb Pearlman  4.9 out of 5 stars             349  $12.28
# 36              Bob Woodward  4.7 out of 5 stars           7,444  $17.72
# 37         Brittany Williams  4.6 out of 5 stars           2,721   $9.99
# 38           Don Miguel Ruiz  4.7 out of 5 stars          25,763   $6.48
# 39               James Clear  4.8 out of 5 stars          14,055  $16.20
# 40               Tana French  4.4 out of 5 stars             672  $16.19
# 41               School Zone  4.6 out of 5 stars           7,202   $2.99
# 42        Workman Publishing  4.8 out of 5 stars           5,666   $5.90
# 43            Maurice Sendak  4.8 out of 5 stars          11,012   $5.00
# 44              Brit Bennett  4.5 out of 5 stars          13,281  $16.20
# 45               Craig Smith  4.8 out of 5 stars         115,670   $4.85
# 46              Anna Dewdney  4.7 out of 5 stars           6,644   $2.89
# 47           Bill Martin Jr.  4.8 out of 5 stars          12,136   $5.00
# 48              Gary Chapman  4.8 out of 5 stars          27,534   $8.99
# 49                Jay Shetty  4.9 out of 5 stars           4,032  $16.20
# 50                James Dean  4.8 out of 5 stars             843   $6.28
# 51             Jocko Willink  4.9 out of 5 stars           2,278  $15.66
# 52    America's Test Kitchen  4.6 out of 5 stars           4,703  $20.26
# 53               Delia Owens  4.8 out of 5 stars          97,729  $15.34
# 54            Alice Schertle  4.8 out of 5 stars           3,721   $7.52
# 55              Andrew Cuomo  4.4 out of 5 stars               9  $18.00
# 56  Bessel van der Kolk M.D.  4.8 out of 5 stars          13,643  $12.98
# 57         Emily Nagoski PhD  4.6 out of 5 stars             439  $15.30
# 58            Jerry Seinfeld  4.2 out of 5 stars              80  $21.00
# 59           Lucasfilm Press  4.9 out of 5 stars           1,325   $5.61
# 60              Rick Riordan  4.8 out of 5 stars           1,069  $19.89
#
# [61 rows x 5 columns]
